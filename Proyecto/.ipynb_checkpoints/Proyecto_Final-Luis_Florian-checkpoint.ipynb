# %% [markdown]
# ## **Predicción de precios de casas**
#
# El siguiente proyecto consiste en crear modelos predictivos de regresión lineal uni-variable sencillos de la forma:
#
# **$ y = f(x) =  mx+b $**
#
# Donde:
#
# $y$ = la variable dependiente\
# $x$ = variable independiente\
# $m$ = pendiente de la recta(parámetro del modelo)\
# $b$ = intercepto(parámetro del modelo)
#
# Se trabajara con un set de datos de muchas variables y se realiza un análisis exploratorio para visualizar y analizar los datos y entender cómo se comportan y luego  elegir las variables independientes “x” a trabajar(según el potencial predictivo de estas a través de medir la correlación), esto significa que aunque el dataset posee múltiples variables, en vez de crear un modelo multi-variable crearemos múltiples modelos uni-variable.

# %% [markdown]
# ### **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### **Importing Data**

# %%
datos = np.load("Dataset/proyecto_training_data.npy")
columnas = ["SalePrice","OverallQual","1stFlrSF","TotRmsAbvGrd","YearBuilt","LotFrontage"]
datos_frame = pd.DataFrame(datos,columns=columnas)

# %% [markdown]
# ### **Análisis Exploratorio**

# %%
datos_frame.describe()
# Out:
#            SalePrice  OverallQual     1stFlrSF  TotRmsAbvGrd    YearBuilt  \
# count    1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean   180921.195890     6.099315  1162.626712      6.517808  1971.267808
# std     79442.502883     1.382997   386.587738      1.625393    30.202904
# min     34900.000000     1.000000   334.000000      2.000000  1872.000000
# 25%    129975.000000     5.000000   882.000000      5.000000  1954.000000
# 50%    163000.000000     6.000000  1087.000000      6.000000  1973.000000
# 75%    214000.000000     7.000000  1391.250000      7.000000  2000.000000
# max    755000.000000    10.000000  4692.000000     14.000000  2010.000000
#
#        LotFrontage
# count  1201.000000
# mean     70.049958
# std      24.284752
# min      21.000000
# 25%      59.000000
# 50%      69.000000
# 75%      80.000000
# max     313.000000

# %% [markdown]
# Se muestra que a la columna $LotFrontage$ le faltan 259 valores. Los valores faltantes o nan Estos serán reemplazados con la media (70.049958).

# %%
inds = np.where(np.isnan(datos))
inds
# Out:
# (array([   7,   12,   14,   16,   24,   31,   42,   43,   50,   64,   66,
#           76,   84,   95,  100,  104,  111,  113,  116,  120,  126,  131,
#          133,  136,  147,  149,  152,  153,  160,  166,  169,  170,  177,
#          180,  186,  191,  203,  207,  208,  214,  218,  221,  234,  237,
#          244,  249,  269,  287,  288,  293,  307,  308,  310,  319,  328,
#          330,  335,  342,  346,  347,  351,  356,  360,  361,  364,  366,
#          369,  370,  375,  384,  392,  393,  404,  405,  412,  421,  426,
#          447,  452,  457,  458,  459,  465,  470,  484,  490,  496,  516,
#          518,  529,  537,  538,  539,  541,  545,  559,  560,  564,  569,
#          580,  593,  610,  611,  612,  616,  623,  626,  641,  645,  660,
#          666,  668,  672,  679,  682,  685,  687,  690,  706,  709,  714,
#          720,  721,  726,  734,  745,  746,  751,  757,  770,  783,  785,
#          789,  791,  794,  811,  816,  817,  822,  828,  840,  845,  851,
# ...

# %% [markdown]
# Se confirma que la única columna con datos faltantes es la número $5$, $LotFrontage$.  Por lo que se procederá a reemplazar los valores faltantes por la media.

# %% [markdown]
# ### **Remplazar datos faltantes**

# %%
datos = np.nan_to_num(datos,nan=70.049958)
datos_frame = pd.DataFrame(datos,columns=columnas)

# %% [markdown]
# Ahora sí, el dataset no contiene datos faltantes.

# %% [markdown]
# ### **Análisis Exploratorio sin datos faltantes**
# En los requerimientos del proyecto únicamente se solicita media, max, min, rango y desviación estándar.  Se ajustará para presentar únicamente estos datos de Estadística Descriptiva.

# %%
df_describe = datos_frame.describe() 
df_describe = df_describe.append(pd.Series(datos_frame.max()-datos_frame.min(),name="range")) # adding range
df_describe = df_describe.drop(["count","25%","50%","75%"]) #eliminamos datos no solicitados.
df_describe
# Out:
#            SalePrice  OverallQual     1stFlrSF  TotRmsAbvGrd    YearBuilt  \
# mean   180921.195890     6.099315  1162.626712      6.517808  1971.267808
# std     79442.502883     1.382997   386.587738      1.625393    30.202904
# min     34900.000000     1.000000   334.000000      2.000000  1872.000000
# max    755000.000000    10.000000  4692.000000     14.000000  2010.000000
# range  720100.000000     9.000000  4358.000000     12.000000   138.000000
#
#        LotFrontage
# mean     70.049958
# std      22.024023
# min      21.000000
# max     313.000000
# range   292.000000

# %% [markdown]
# ### **Spliting data in train and testing dataset**
# Por medio de slicing se procede a dividir el dataset original en dos subsets, train para entrenamiento y test para pruebas.

# %%
#Training = 1460 * 0.80 = 1168
train, test = datos[:1168,:], datos[1168:,:]
print("Training size:",train.shape)
print("Testing size:",test.shape)
# Out:
# Training size: (1168, 6)
# Testing size: (292, 6)

# %% [markdown]
# ### **Histograma de variables**

# %%
colors = ["m","y","g","b","c","r"]
f,axes = plt.subplots(3,2,sharex=False, figsize=(17,17))

# // -> Floor division, % modulus
for i in range(0,len(columnas)): 
    sns.histplot(datos_frame[columnas[i]] , color=colors[i], kde=True, ax=axes[i//2, i%2])
    
plt.show()

# %% [markdown]
# ### **Correlación**

# %%
correlation = []
for i in range(1,len(columnas)): #SalePrice es la columna 0
    correlation.append(datos_frame[columnas[0]].corr(datos_frame[columnas[i]]))

corr = pd.Series(correlation, name=columnas[0], index=columnas[1:])
corr.to_frame().T
# Out:
#            OverallQual  1stFlrSF  TotRmsAbvGrd  YearBuilt  LotFrontage
# SalePrice     0.790982  0.605852      0.533723   0.522897     0.334901

# %%
f,axes = plt.subplots(3,2,sharex=False, figsize=(16,16))
f.delaxes(axes[2,1]) # Son 5 gráficas, por lo que eliminamos el espacio (2,1)

for i in range(1,len(columnas)):
    plt.subplot(3,2,i)
    plt.scatter(datos_frame[columnas[i]], datos_frame[columnas[0]])
    plt.title("Correlación SalePrice y "+ columnas[i] +" = " + str(round(corr[columnas[i]],4))) 

plt.show()

# %% [markdown]
# Se observa que las dos variables con mayor correlación son **$OverallQual$** y **$1stFlrSF$**

# %% [markdown]
# ### **Modelo de Regresión Lineal de una variable**

# %%
def training (x,y,epochs,imprimir_error_cada,lr):
    m,b = 0.0,0.0 # Inicializamos m y b con 0 para la primera iteración.
    parametros = np.array([m,b])  # [m,b]
    errors = np.zeros(epochs) # Error vector with epoch size.
    modelo = {}  # Estructura para guardar las predicciones de cada iteración   
    xx = x.reshape(len(x),1)
    xx = np.insert(xx,1,np.ones_like(x),axis=1) #Crear Matriz x de 2 columnas con "1"    
    
    for i in range(epochs):
        yhat = np.dot(xx,parametros) #yhat = mx+b         
        errors[i] = (np.average((y-yhat)**2))/2   
        gradientes = np.dot(yhat-y,xx)/len(y)
        parametros -= (lr * gradientes)
        modelo[i] = parametros.copy()
        
        if ((i+1) % imprimir_error_cada) == 0:
            print(f"Error Iteración {i+1}: ",errors[i])       
        
    return (modelo,errors)

# %% [markdown]
# ### **Función para graficar errores**

# %%
def graphErrores (errores):
    x = range(0,len(errores))
    y = errores
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    
    ax.grid()
    ax.plot(x,errores, label = "Train Loss")
    
    ax.legend()
    ax.set_title("Losses")
    ax.set_ylabel('Errors')
    ax.set_xlabel('Iteracion')
    
    plt.show()

# %% [markdown]
# ### **Función de evolución del modelo entrenado en el tiempo**
# Crear una función que nos permita visualizar con matplotlib cómo evoluciona el modelo entrenado en el tiempo

# %%
def graphTraining(x,y,parametros, n):    
    
    #Ceiling division -(n // -d)
    filas_plots = -((len(parametros)//n) // -2)    
    
    f,axes = plt.subplots(filas_plots,2,sharex=False, figsize=(15,20))    
    
    xx = x.reshape(len(x),1)
    xx = np.insert(xx,1,np.ones_like(x),axis=1) #Crear Matriz x de 2 columnas con "1"     
    pos = 1 #Graph Position
    
    for i in range(n-1,len(modelo),n):  #Remembering first iteration starts at position 0 
        yhat = np.dot(xx,parametros[i]) #yhat = mx+b
        m = round(parametros[i][0],2)
        b = round(parametros[i][1],2)
        
        plt.subplot(filas_plots,2,pos)
        pos+=1
        
        
        plt.scatter(x,y)
        plt.plot(x,yhat, color='r')
        
        plt.title(f"Iteración No={i+1}, m={m}, b={b}")
    
    plt.show()

# %% [markdown]
# ### **Entrenamiento variable OverallQuality (lr = 0.05)**
# Se calculará el error con learning rate (lr) de 0.5 y 30,000 iteraciones, imprimiendo el resultado cada 2,000 iteraciones.

# %%
epochs = 30000
error = 2000
lr = 0.05 #0.0001
#train[:,0] --> PriceSale
#train[:,1] -->OverallQual	
modelo_Overall, errores = training(train[:,1],train[:,0],epochs,error,lr)
graphErrores(errores)
#graphTraining(train[:,1],train[:,0],modelo,5000)
# Out:
# Error Iteración 2000:  3.465199503290999e+16
# Error Iteración 4000:  6.713777119052704e+22
# Error Iteración 6000:  1.3007852694606258e+29
# Error Iteración 8000:  2.520253930449903e+35
# Error Iteración 10000:  4.8829580277949396e+41
# Error Iteración 12000:  9.46066537705864e+47
# Error Iteración 14000:  1.832991167794931e+54
# Error Iteración 16000:  3.551395686566318e+60
# Error Iteración 18000:  6.880781284808226e+66
# Error Iteración 20000:  1.333142101523548e+73
# Error Iteración 22000:  2.582944856538443e+79
# Error Iteración 24000:  5.004420852277929e+85
# Error Iteración 26000:  9.695997962684277e+91
# Error Iteración 28000:  1.8785865391307442e+98
# Error Iteración 30000:  3.639736104098865e+104

# %% [markdown]
# Se observa que el error aumenta.  Por lo que un learning rate de 0.05 no es el adecuado.

# %% [markdown]
# ### **Entrenamiento variable OverallQuality (lr = 0.0001)**
# Se modifica el learning rate y se reduce la cantidad de iteraciones, para observar el cambio.

# %%
epochs = 1000
error = 100
lr = 0.0001
modelo_Overall, errores = training(train[:,1],train[:,0],epochs,error,lr)
graphErrores(errores)
graphTraining(train[:,1],train[:,0],modelo_Overall,100)
# Out:
# Error Iteración 100:  9529508397.186686
# Error Iteración 200:  5038410635.515039
# Error Iteración 300:  3026467600.11068
# Error Iteración 400:  2125076747.3682766
# Error Iteración 500:  1721164452.2871947
# Error Iteración 600:  1540100749.056787
# Error Iteración 700:  1458863515.8884373
# Error Iteración 800:  1422344263.7205887
# Error Iteración 900:  1405856817.9830375
# Error Iteración 1000:  1398342860.2789438

# %% [markdown]
# Se observa que esta vez con lr=0.0001 el error si disminuye y se mantiene a así a un ritmo adecuado.  También, con 1,000 iteraciones se logra observar como yhat se ajusta cada vez más.

# %% [markdown]
# ### **Entrenamiento variable 1stFlrSF (lr = 0.000009)**

# %%
epochs = 100
error = 10
lr = 0.000009
modelo, errores = training(train[:,2],train[:,0],epochs,error,lr)
graphErrores(errores)
#graphTraining(train[:,1],train[:,0],modelo,100)
# Out:
# Error Iteración 10:  7.138095468572564e+29
# Error Iteración 20:  4.412535887386182e+51
# Error Iteración 30:  2.727684582420508e+73
# Error Iteración 40:  1.6861649108494648e+95
# Error Iteración 50:  1.0423316995313996e+117
# Error Iteración 60:  6.443351803001773e+138
# Error Iteración 70:  3.983068199490708e+160
# Error Iteración 80:  2.462201780508577e+182
# Error Iteración 90:  1.5220521729240718e+204
# Error Iteración 100:  9.408826016787179e+225

# %% [markdown]
# ### **Entrenamiento variable 1stFlrSF (lr = 0.000001)**
# Modificamos lr y aumentamos las iteraciones

# %%
epochs = 1000
error = 100
lr = 0.000001
modelo_1flrsf, errores = training(train[:,2],train[:,0],epochs,error,lr)
graphErrores(errores)
graphTraining(train[:,2],train[:,0],modelo_1flrsf,120)
# Out:
# Error Iteración 100:  1968092273.0876758
# Error Iteración 200:  1968091451.3653347
# Error Iteración 300:  1968090629.6585293
# Error Iteración 400:  1968089807.967259
# Error Iteración 500:  1968088986.2915235
# Error Iteración 600:  1968088164.6313226
# Error Iteración 700:  1968087342.9866567
# Error Iteración 800:  1968086521.357524
# Error Iteración 900:  1968085699.7439258
# Error Iteración 1000:  1968084878.1458607

# %% [markdown]
# Se observa que con pocas iteraciones la pendiente no cambia y el error se mantiene con pocos cambios aunque disminuyendo.

# %% [markdown]
# ### **Entrenamiento del modelo con scikit-learn (OverallQuality)**

# %%
x = train[:,1].reshape(-1,1) # Convering to matrix
y = train[:,0].reshape(-1,1)

lreg_Overall = LinearRegression()
lreg_Overall.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Entrenamiento con variable 1stFlrSF** (scikit-learn)

# %%
x = train[:,2].reshape(-1,1) #1stFlSF
y = train[:,0].reshape(-1,1) #SalesPrice

lreg_1flrsf = LinearRegression()
lreg_1flrsf.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Predicciones de Ambos Modelos con Datos de Prueba**

# %%
def predictions(x, manual_model, sl_model):
    '''Esta función recibe los modelos y retorna las predicciones'''
    ones = np.ones((x.shape[0],1))
    data = np.hstack((x,ones))
    
    manual_pred = np.matmul(data,manual_model)
    sl_pred = sl_model.predict(x)
    avg = (manual_pred + sl_pred)/2
        
    return manual_pred, sl_pred, avg


def calcular_error(y,yhat):
    return (0.5 * (np.average((y-yhat)**2)))

# %% [markdown]
# ### **Cálculo de predicciones y error en variable OverallQuality**

# %%
x = test[:,1].reshape(-1,1) #OverallQuality
y = test[:,0].reshape(-1,1) #SalesPrice

manual_Overall, skl_Overall, avg_Overall = predictions(x, modelo_Overall[(len(modelo_Overall)-1)], lreg_Overall)
manual_error_Overall = calcular_error(y,manual_Overall)
sl_error_Overall = calcular_error(y,skl_Overall)
avg_error_Overall = calculate_error(y,avg_Overall)

print(f"Error Modelo Manual: {round(manual_error_Overall,2)}")
print(f"Error Modelo scikit-learn: {round(sl_error_Overall,2)}")
print(f"Error Promedio: {round(avg_error_Overall,2)}")
# Out:
# Error Modelo Manual: 4189652134.14
# Error Modelo scikit-learn: 1315091304.47
# Error Promedio: 2035676501.38

# %% [markdown]
# ## **Cálculo de predicciones y error en variable 1stFlrSF**

# %%
x = test[:,2].reshape(-1,1) ##1stFlrSF
y = test[:,0].reshape(-1,1) ##SalesPrice

manual_1flrsf, skl_1flrsf, avg_1flrsf = predictions(x, modelo_1flrsf[(len(modelo_1flrsf)-1)], lreg_1flrsf )
manual_error_1flrsf = calcular_error(y,manual_1flrsf)
sl_error_1flrsf = calcular_error(y,skl_1flrsf)
avg_error_1flrsf = calcular_error(y,avg_1flrsf)

print(f"Error Modelo Manual: {round(manual_error_1flrsf,2)}")
print(f"Error Modelo scikit-learn: {round(sl_error_1flrsf,2)}")
print(f"Error Promedio: {round(avg_error_1flrsf,2)}")
# Out:
# Error Modelo Manual: 5568199023.99
# Error Modelo scikit-learn: 2292769137.35
# Error Promedio: 2980101933.38

# %% [markdown]
# ### **Comparación de errores obtenidos en cada modelo**

# %%
f, ax = plt.subplots(figsize=(10,8))
labels = [columnas[1], columnas[2]]
width = 0.30
x_plt = np.arange(len(labels))

rects1 = ax.bar(x_plt, (manual_error_Overall,manual_error_1flrsf), width, label='Manual')
rects2 = ax.bar(x_plt + width, (sl_error_Overall,sl_error_1flrsf), width, label='scikit-learn')
rects3 = ax.bar(x_plt + (2*width), (avg_error_Overall,avg_error_1flrsf), width, label='Promedio')

ax.set_ylabel('Error')
ax.set_title('Grafica de Errores por variable')
ax.set_xticks(x_plt + width)
ax.set_xticklabels(labels)
ax.legend()
plt.show()

# %% [markdown]
# ### **Conclusión**

# %% [markdown]
# Se observa en la gráfica que el modelo con menor error para ambas variables, es el obtenido por medio de Scikit-Learn.
